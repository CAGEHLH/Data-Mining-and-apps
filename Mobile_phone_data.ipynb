# %% [markdown]
# <a href="https://colab.research.google.com/github/CAGEHLH/Data-Mining-and-apps/blob/main/Mobile_phone_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

mobilephone = pd.read_csv("https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/mobile_phone.csv")
mobilephone.head()
# Out:
#    battery_power_mAh  clock_speed dual_sim  front_cam_mp  5G  int_memory_gb  \
# 0               1650          2.3       no             0   1             38
# 1               1093          1.1      yes             0   0             42
# 2               1934          2.6      yes             0   1             46
# 3                825          0.5      yes             0   1             23
# 4               1156          2.3      yes             0   1              3
#
#    thickness_cm  weight_grams  n_cores  back_cam_mp  ram_mb  screen_height_cm  \
# 0           0.7            89        1            1     324                14
# 1           0.4           114        1            4    2856                12
# 2           0.1           103        1           17    2940                13
# 3           0.1            86        2            0    3278                 8
# 4           1.0            95        2            0    3786                11
#
# ...
